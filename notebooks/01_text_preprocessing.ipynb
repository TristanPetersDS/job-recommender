# %% [markdown]
# # **Data Intake and Preview**

# %% [markdown]
# ## **1. Introduction**

# %% [markdown]
# ### **Notebook Overview**

# %% [markdown]
# This notebook prepares the textual data for the **Resume-to-Job Recommendation System**, which aims to recommend job postings to users based on the similarity of their resumes to available roles. To enable effective classification and content-based retrieval, we create a **unified preprocessing pipeline** that cleans and normalizes the text data for **TF-IDF feature extraction**. This ensures consistency across resumes and job descriptions, which is critical for computing cosine similarity and training our classification models later in the pipeline.
#
# The output will be clean, lemmatized, and consistently formatted text, enabling downstream tasks such as TF-IDF vectorization, embedding generation, and feature analysis. All logic is modular and reusable to support future enhancements.

# %% [markdown]
# ---

# %% [markdown]
# ### **Objectives**

# %% [markdown]
# - Develop a **single, reusable cleaning pipeline** for textual data using `spaCy`.
# - Normalize, clean, and lemmatize text for both resumes and job descriptions.
# - Create derived features for exploratory data analysis.
# - Save preprocessed, clean datasets for downstream modeling and matching phases.

# %% [markdown]
# ---

# %% [markdown]
# ### **Dataset Descriptions**

# %% [markdown]
# #### **Linkedin Job Postings Dataset**

# %% [markdown]
# [LinkedIn Job Postings (2023 - 2024)](https://www.kaggle.com/datasets/arshkon/linkedin-job-postings) by [Arsh Koneru](https://www.kaggle.com/arshkon) and [Zoey Yu Zou](https://www.kaggle.com/zoeyyuzou)
# - Contains job titles, descriptions, industries, and metadata.
# - We primarily focus on the `title` and `description` fields for text processing.

# %% [markdown]
# #### **Resume Dataset**

# %% [markdown]
# [Resume Dataset](https://www.kaggle.com/datasets/snehaanbhawal/resume-dataset/data) by [Snehaan Bhawal](https://www.kaggle.com/snehaanbhawal)
# - Contains labeled résumé texts (`Resume_str`) across multiple categories.
# - The `Category` field serves as the ground-truth label for classifier training.

# %% [markdown]
# ---

# %% [markdown]
# ### **Importing Packages**

# %%
import pandas as pd
import numpy as np
from pandarallel import pandarallel

# %%
from jobrec import config
from jobrec import preprocessing as pp
from jobrec import feature_extractor as fe
from jobrec import visualizer as vis
from jobrec import utilities as util
from jobrec.spacy_df_io import save_spacy_df
# Out:
# INFO: Pandarallel will run on 32 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %% [markdown]
# ---

# %% [markdown]
# ## **2. Data Overview**

# %% [markdown]
# ### **2.1 Initial Inspections**
# Here we will load in and take an initial look at our datasets to see what condition they are in.

# %%
# Load in datasets
jobs_df = pd.read_pickle(config.RAW_DATA_DIR/'jobs_raw.pkl')
resume_df = pd.read_csv(config.RAW_DATA_DIR/'resumes_raw.csv')

# %% [markdown]
# #### **Jobs Dataset**

# %%
# Initial View
jobs_df.head()
# Out:
#      job_id            company_name  \
# 0    921716   Corcoran Sawyer Smith
# 1   1829192                     NaN
# 2  10998357  The National Exemplar
# 3  23221523  Abrams Fensterman, LLP
# 4  35982263                     NaN
#
#                                                title  \
# 0                              Marketing Coordinator
# 1                  Mental Health Therapist/Counselor
# 2                        Assitant Restaurant Manager
# 3  Senior Elder Law / Trusts and Estates Associat...
# 4                                 Service Technician
#
#                                          description  max_salary pay_period  \
# 0  Job descriptionA leading real estate firm in N...        20.0     HOURLY
# 1  At Aspen Therapy and Wellness , we are committ...        50.0     HOURLY
# 2  The National Exemplar is accepting application...     65000.0     YEARLY
# 3  Senior Associate Attorney - Elder Law / Trusts...    175000.0     YEARLY
# ...

# %%
# Dataframe info
jobs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123849 entries, 0 to 123848
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   job_id                      123849 non-null  int64
#  1   company_name                122130 non-null  object
#  2   title                       123849 non-null  object
#  3   description                 123842 non-null  object
#  4   max_salary                  29793 non-null   float64
#  5   pay_period                  36073 non-null   object
#  6   location                    123849 non-null  object
#  7   company_id                  122132 non-null  float64
#  8   views                       122160 non-null  float64
#  9   med_salary                  6280 non-null    float64
#  10  min_salary                  29793 non-null   float64
#  11  formatted_work_type         123849 non-null  object
# ...

# %%
# Plot percentage of missing data for each feature
vis.plot_missing_data(jobs_df, save_plot=True, save_dir=config.FIGURES_DIR, filename_prefix='01_preprocessing_jobs')

# %% [markdown]
# From this plot, we can see that there is a huge amount of missing data. \
# There are two likely causes for this:
# 1. Job listings are missing key information
# 2. **The web scraping utility failed to detect and parse these sections properly**
#
# Based on the types of features with large fractions of missing data, it is more probable to be **option 2**. If this is the case, any data actually found within these features is likely to be inconsistent and will not be suitable for study.

# %% [markdown]
# # Check for duplicate entries
# print(jobs_df.nunique())
#
# if jobs_df['job_id'].duplicated().any() == False:
#     print("No duplicate IDs found!")
# else:
#     print("Duplicates found!")

# %%
# Summary Statistics
jobs_df.describe()
# Out:
#              job_id    max_salary    company_id          views     med_salary  \
# count  1.238490e+05  2.979300e+04  1.221320e+05  122160.000000    6280.000000
# mean   3.896402e+09  9.193942e+04  1.220401e+07      14.618247   22015.619876
# std    8.404355e+07  7.011101e+05  2.554143e+07      85.903598   52255.873846
# min    9.217160e+05  1.000000e+00  1.009000e+03       1.000000       0.000000
# 25%    3.894587e+09  4.828000e+01  1.435200e+04       3.000000      18.940000
# 50%    3.901998e+09  8.000000e+04  2.269650e+05       4.000000      25.500000
# 75%    3.904707e+09  1.400000e+05  8.047188e+06       8.000000    2510.500000
# max    3.906267e+09  1.200000e+08  1.034730e+08    9975.000000  750000.000000
#
#          min_salary       applies  original_listed_time  remote_allowed  \
# count  2.979300e+04  23320.000000          1.238490e+05         15246.0
# mean   6.491085e+04     10.591981          1.713152e+12             1.0
# ...

# %%
# Sample Job Listing
print("Job Title:", jobs_df['title'].iloc[0])
print("Job Summary:\n", jobs_df['description'].iloc[0])
# Out:
# Job Title: Marketing Coordinator
# Job Summary:
# ...

# %% [markdown]
# #### **Notes on Jobs Dataset:**
# - Dataset has a wide range of features, not all of which are useful our goal of NLP-based job recommendation.
# - Several of the features are missing a significant amount of data.
# - Description contains additional fields; the original scraping likely failed to parse the sections properly.
#
# It seems that the `description` field will contain all of the textual information we'll need.

# %% [markdown]
# #### **Resume Dataset**

# %%
# Initial View
resume_df.head()
# Out:
#          ID                                         Resume_str  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2  33176873           HR DIRECTOR       Summary      Over 2...
# 3  27018550           HR SPECIALIST       Summary    Dedica...
# 4  17812897           HR MANAGER         Skill Highlights  ...
#
#                                          Resume_html Category
# 0  <div class="fontsize fontface vmargins hmargin...       HR
# 1  <div class="fontsize fontface vmargins hmargin...       HR
# 2  <div class="fontsize fontface vmargins hmargin...       HR
# 3  <div class="fontsize fontface vmargins hmargin...       HR
# 4  <div class="fontsize fontface vmargins hmargin...       HR

# %%
# Dataframe information
resume_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           2484 non-null   int64
#  1   Resume_str   2484 non-null   object
#  2   Resume_html  2484 non-null   object
#  3   Category     2484 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 77.8+ KB

# %% [markdown]
# # Check for unique entries
# print(resume_df.nunique())
#
# if resume_df['ID'].duplicated().any() == False:
#     print("No duplicates found!")
# else:
#     print("Duplicates found!")

# %%
# Sample Resume
print(resume_df['Resume_str'].iloc[0])
# Out:
#          HR ADMINISTRATOR/MARKETING ASSOCIATE
#
# ...

# %% [markdown]
# #### **Notes on Resume Dataset:**
# - Resume dataset has significantly less entries than the Jobs Dataset.
# - We have two routes of data processing with `Resume_str` and `Resume_html`.
# - While `Resume_html` could potentially be used to extract a richer and more complete feature set, for the purpose of this capstone we will opt to use `Resume_str`.

# %% [markdown]
# ### **2.2 Jobs Dataset Pruning**
# Each dataset contains unnecessary features. In order to minimize time spend processing data, we will first prune our datasets to ensure data completeness.

# %% [markdown]
# #### **Jobs Dataset**
# The Linkedin job listings dataset contains a wide variety of interesting features. While any number of investigations could be performed using the available data, we will limit ourselves to features relevant to our prototype NLP job recommender.

# %%
# Remove all unnecessary features
jobs_df = jobs_df[['job_id', 'title', 'description', 'skill_name', 'industry_name']]

# %%
# Check missing data
util.check_missing(jobs_df)
# Out:
#                Missing  Total % Missing
# skill_name        1753         1.415433
# industry_name     1436         1.159476
# description          7         0.005652
# job_id               0         0.000000
# title                0         0.000000

# %%
# Drop listings with no description
jobs_df = jobs_df[jobs_df['description'].notna() == True]

# Drop listings with no skills or industry mapping
jobs_df = jobs_df[jobs_df['skill_name'].notna() == True]
jobs_df = jobs_df[jobs_df['industry_name'].notna() == True]

# Reset dataframe index
jobs_df.reset_index(drop=True, inplace=True)

# %%
# Check missing data again
util.check_missing(jobs_df)
# Out:
#                Missing  Total % Missing
# job_id               0              0.0
# title                0              0.0
# description          0              0.0
# skill_name           0              0.0
# industry_name        0              0.0

# %%
# Check duplicates
util.check_duplicates(jobs_df)
# Out:
#                Unique Entries  Duplicate Count  Ratio Unique (%)
# skill_name               2241           118628          1.854073
# industry_name            4669           116200          3.862860
# title                   70857            50012         58.622972
# description            104900            15969         86.788176
# job_id                 120869                0        100.000000

# %% [markdown]
# It is fully expected to have `skill_name`, `industry_name`, and `title` as having high duplicate entries. There are only so many skills, industries, and job titles. While it is nice that there are no repeated entries for `job_id` it is concerning that we have duplicates of `description`.

# %%
# Drop duplicates
jobs_df = jobs_df.drop_duplicates(subset=['description'], keep='first')

# %%
# Check duplicates
util.check_duplicates(jobs_df)
# Out:
#                Unique Entries  Duplicate Count  Ratio Unique (%)
# skill_name               2238           102662          2.133460
# industry_name            4646           100254          4.428980
# title                   68275            36625         65.085796
# job_id                 104900                0        100.000000
# description            104900                0        100.000000

# %%
# View of pruned dataset
jobs_df.head()
# Out:
#      job_id                                              title  \
# 0    921716                              Marketing Coordinator
# 1  10998357                        Assitant Restaurant Manager
# 2  23221523  Senior Elder Law / Trusts and Estates Associat...
# 3  35982263                                 Service Technician
# 4  91700727           Economic Development and Planning Intern
#
#                                          description  \
# 0  Job descriptionA leading real estate firm in N...
# 1  The National Exemplar is accepting application...
# 2  Senior Associate Attorney - Elder Law / Trusts...
# 3  Looking for HVAC service tech with experience ...
# 4  Job summary:The Economic Development & Plannin...
#
#                     skill_name                         industry_name
# 0           [marketing, sales]                         [real estate]
# 1  [manufacturing, management]                         [restaurants]
# ...

# %%
# Save cleaned dataset
jobs_df.to_pickle(config.CLEANED_DATA_DIR/'jobs_clean.pkl')

# %% [markdown]
# #### **Resume Dataset**
# The resume dataset has two fields of note we could etract features from, `Resume_str` and `Resume_html`. While a much more thorough analysis could be performed by parsing the raw html and effectively reconstructing more true to form resume sections, we will simply use the precompiled string data for proof-of-concept prototyping.

# %%
# Rename columns and remove unnecessary features
resume_df['resume']   = resume_df['Resume_str']
resume_df['category'] = resume_df['Category']
resume_df = resume_df[['category', 'resume']]

# %%
# Check missing data
util.check_missing(resume_df)
# Out:
#           Missing  Total % Missing
# category        0              0.0
# resume          0              0.0

# %%
# Check duplicates
util.check_duplicates(resume_df)
# Out:
#           Unique Entries  Duplicate Count  Ratio Unique (%)
# category              24             2460          0.966184
# resume              2482                2         99.919485

# %% [markdown]
# It is fully expected for there to be duplicated categories. We will drop duplicated entries in the `resume` field.

# %%
# Drop duplicates
resume_df = resume_df.drop_duplicates(subset=['resume'], keep='first')

# %%
# Check duplicates
util.check_duplicates(resume_df)
# Out:
#           Unique Entries  Duplicate Count  Ratio Unique (%)
# category              24             2458          0.966962
# resume              2482                0        100.000000

# %%
# View of pruned dataset
resume_df.head()
# Out:
#   category                                             resume
# 0       HR           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1       HR           HR SPECIALIST, US HR OPERATIONS      ...
# 2       HR           HR DIRECTOR       Summary      Over 2...
# 3       HR           HR SPECIALIST       Summary    Dedica...
# 4       HR           HR MANAGER         Skill Highlights  ...

# %%
# Save cleaned dataset
resume_df.to_pickle(config.CLEANED_DATA_DIR/'resumes_clean.pkl')

# %% [markdown]
# ## **3. Data Preprocessing**

# %% [markdown]
# ### **Text Cleaning Pipeline**
#
# Modern resumes and job postings often include noise — punctuation, special characters, filler words, repeated boilerplate — that weakens NLP feature extraction.
#
# This notebook applies the following pipeline of custom functions:
# 1. `regex_text`:
#     - **Lowercase** and standardize text
#     - **Remove URLs, emails, and special characters** with regex
# 2. `lemmatize_text`:
#     - Built with **spaCy**; a high-performance NLP library
#     - **Tokenize** text into individual words
#     - **Remove stopwords** to keep only meaningful terms
#     - **Lemmatize** words to their root form (e.g., *running* → *run*) for semantic consistency
# 4. `extract_skills`:
#     - Identifies and extracts skills from processed text
#     - `SKILLS` list manually defined in `config.py`
# 5.  `extract_domains`:
#     - Identifies and extracts domains from preprocessed text and extracted skills list
#     - Infers broader knowledge domains from detected skills
#     - `DOMAINS` list manually defined in `config.py`
#
# Both datasets are passed through this pipeline equally, ensuring **identical treatment** of both resumes and job descriptions.

# %%
# RUNTIME SWITCH
if config.QUICKRUN:
    jobs_df   = jobs_df.sample(config.N_SAMPLE_JOBS, random_state=config.RANDOM_SEED)
    resume_df = resume_df.sample(config.N_SAMPLE_RESUMES, random_state=config.RANDOM_SEED)

# %%
# Clean text in job title
jobs_df['title_clean'] = jobs_df['title'].parallel_apply(pp.regex_text)

# %%
# Apply preprocessing to job listing descriptions
jobs_df = pp.preprocessing_pipeline(
    df=jobs_df,
    text_column="description",
    prefix="desc_",
    regex_func=pp.regex_text,
    lemmatize_func=pp.lemmatize_text,
    extract_skills_func=pp.extract_skills,
    extract_domains_func=pp.extract_domains,
    return_docbin=config.SPACY_MODE
)

# %%
# Apply preprocessing to resumes
resume_df = pp.preprocessing_pipeline(
    df=resume_df,
    text_column="resume",
    prefix="resume_",
    regex_func=pp.regex_text,
    lemmatize_func=pp.lemmatize_text,
    extract_skills_func=pp.extract_skills,
    extract_domains_func=pp.extract_domains,
    return_docbin=config.SPACY_MODE
)

# %% [markdown]
# ---

# %% [markdown]
# ## **4. Feature Extraction**

# %% [markdown]
# ### **Text Cleaning Pipeline**
# This notebook applies the following pipeline of custom functions to perform feature extraction:
# 1. `compute_text_length`: Text length
# 2. `compute_avg_word_length`: Mean length of all words
# 3. `compute_unique_word_count`:  Number of distinct words
# 4. `compute_lexical_diversity`:  Unique/total word ratio

# %% [markdown]
# ### **Job Postings Dataset**

# %%
# Apply text feature pipeline to processed linkedin dataset
jobs_df = fe.text_features_pipeline(jobs_df, text_column="desc_clean", prefix="desc_")

# %%
# View dataframe
jobs_df.head()
# Out:
#            job_id                                              title  \
# 56812  3901953536                                Major Gifts Officer
# 78891  3903849447  Research Scientist , Selling Partner Experienc...
# 57565  3901961521  Springboard Innovation Fellow at Hillel at The...
# 93764  3904946151                            Senior Internal Auditor
# 70157  3902876622                   Sales Manager - Southeast Region
#
#                                              description  \
# 56812  Employment Type: Full-time, ExemptWage: A comp...
# 78891  Description\n\nDo you want to join an innovati...
# 57565  Springboard Fellow \n\nHillel at The George Wa...
# 93764  \nPosition Overview:Join our client's team as ...
# 70157  About Calico Brands, Inc.We are a consumer pro...
#
#                                         skill_name  \
# 56812                                      [other]
# 78891             [research, engineering, science]
# ...

# %%
# View information on jobs dataframe
jobs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 56812 to 88210
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   job_id                  5000 non-null   int64
#  1   title                   5000 non-null   object
#  2   description             5000 non-null   object
#  3   skill_name              5000 non-null   object
#  4   industry_name           5000 non-null   object
#  5   title_clean             5000 non-null   object
#  6   desc_clean              5000 non-null   object
#  7   desc_clean_lemmatized   5000 non-null   object
#  8   desc_clean_tokens       5000 non-null   object
#  9   desc_skills             5000 non-null   object
#  10  desc_domains            5000 non-null   object
#  11  desc_text_length        5000 non-null   int64
#  12  desc_avg_word_length    5000 non-null   float64
#  13  desc_unique_word_count  5000 non-null   int64
# ...

# %%
# View summary statistics of processed dataset
jobs_df.describe()
# Out:
#              job_id  desc_text_length  desc_avg_word_length  \
# count  5.000000e+03       5000.000000           5000.000000
# mean   3.897470e+09        538.780800              5.840327
# std    5.078505e+07        307.918549              0.393110
# min    7.053561e+08         15.000000              4.158845
# 25%    3.894411e+09        304.000000              5.584400
# 50%    3.901986e+09        500.000000              5.824492
# 75%    3.904563e+09        720.250000              6.089640
# max    3.906264e+09       2200.000000              8.875000
#
#        desc_unique_word_count  desc_lexical_diversity
# count             5000.000000             5000.000000
# mean               282.871600                0.567531
# std                128.989379                0.091787
# min                 12.000000                0.224730
# 25%                185.000000                0.506667
# 50%                276.000000                0.557116
# ...

# %% [markdown]
# ### **Resume Dataset**

# %%
# Apply text feature pipeline to processed linkedin dataset
resume_df = fe.text_features_pipeline(resume_df, text_column="resume_clean", prefix="resume_")

# %%
# View dataframe
resume_df.head()
# Out:
#                     category  \
# 254   INFORMATION-TECHNOLOGY
# 621     BUSINESS-DEVELOPMENT
# 1731             ENGINEERING
# 1793             ENGINEERING
# 819                  FITNESS
#
#                                                  resume  \
# 254            INFORMATION TECHNOLOGY SPECIALIST(DIS...
# 621            BUSINESS DEVELOPMENT DIRECTOR       S...
# 1731             ENGINEERING MANAGER         Profess...
# 1793           ENGINEERING PROJECT MANAGER III      ...
# 819            PERSONAL TRAINER         Summary    H...
#
#                                            resume_clean  \
# 254   information technology specialist discountpcfi...
# 621   business development director summary i collab...
# 1731  engineering manager professional summary exper...
# 1793  engineering project manager iii summary result...
# 819   personal trainer summary hard working seasoned...
#
#                                 resume_clean_lemmatized  \
# ...

# %%
# View information on resume dataframe
resume_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 254 to 39
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   category                  1000 non-null   object
#  1   resume                    1000 non-null   object
#  2   resume_clean              1000 non-null   object
#  3   resume_clean_lemmatized   1000 non-null   object
#  4   resume_clean_tokens       1000 non-null   object
#  5   resume_skills             1000 non-null   object
#  6   resume_domains            1000 non-null   object
#  7   resume_text_length        1000 non-null   int64
#  8   resume_avg_word_length    1000 non-null   float64
#  9   resume_unique_word_count  1000 non-null   int64
#  10  resume_lexical_diversity  1000 non-null   float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 93.8+ KB

# %%
# View summary statistics of processed dataset
resume_df.describe()
# Out:
#        resume_text_length  resume_avg_word_length  resume_unique_word_count  \
# count         1000.000000             1000.000000               1000.000000
# mean           785.626000                6.175592                349.372000
# std            335.601395                0.352836                113.830615
# min            118.000000                4.519016                 64.000000
# 25%            629.000000                5.997720                289.000000
# 50%            739.000000                6.207628                345.000000
# 75%            918.500000                6.412382                404.000000
# max           3257.000000                7.098408               1023.000000
#
#        resume_lexical_diversity
# count               1000.000000
# mean                   0.467064
# std                    0.079830
# min                    0.144815
# 25%                    0.420556
# 50%                    0.467163
# 75%                    0.514657
# ...

# %% [markdown]
# ### **Save Datasets**

# %%
# Check runtime configs do determine save conditions
if config.SPACY_MODE == True:
    # Save complete DF with spaCy Docs
    save_spacy_df(jobs_df, config.JOB_CORPUS_DIR, doc_cols=None)
    save_spacy_df(resume_df, config.RESUME_CORPUS_DIR, doc_cols=None)
else:
    # Save to pickle
    jobs_df.to_pickle(f"{config.PROCESSED_DATA_DIR / config.JOB_NAME}.pkl")
    resume_df.to_pickle(f"{config.PROCESSED_DATA_DIR / config.RESUME_NAME}.pkl")

# %% [markdown]
# ---

# %% [markdown]
# ## **5. Summary of Work**

# %% [markdown]
# - Applied a single, robust text cleaning function to both datasets
# - Removed noise, standardized tokens, and lemmatized words
# - Created columns for cleaned text, lemmatized text, extracted skills and domains
# - Added derived `text_length`, `avg_word_length`, `unique_word_count`, `lexical_diversity` features for later EDA
# - Saved `jobs_df` and `resume_df` using custom utility to ensure spaCy information is preserved.
#
# **Next:** Continue to `02_eda.ipynb` to analyze class balance, keyword patterns, and feature distributions that will inform the classification model and recommendation engine.
